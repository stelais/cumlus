# %%
import numpy as np

plack_constant = 
speed_of_light =

# %%
def radiative_spectral_emittance(wavelength, temperature):
  I_star = (2 * np.pi * plack_constant * speed_of_light**2) / (wavelength**5 *(np.exp(plack_constant*speed_of_light/(wavelength*boltzmann_constant*temperature))- 1))
